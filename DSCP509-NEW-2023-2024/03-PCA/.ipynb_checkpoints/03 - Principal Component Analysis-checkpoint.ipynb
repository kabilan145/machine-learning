# %% [markdown]
# # PART - A

# %% [markdown]
# ## 1 - Implementation of PCA in Iris Data Set

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA 
from sklearn.preprocessing import StandardScaler
import numpy as np

# %%
data = pd.read_csv("../datasets/Iris.csv")
X = data[data.columns[1:-1]]

# %%
scaled_X= StandardScaler().fit_transform(X)
reduced_X = PCA(n_components=2).fit_transform(scaled_X)

# %%
plt.figure(figsize=(7,7))
sns.scatterplot(x=np.ndarray.ravel(reduced_X[:,:1]),
                y=np.ndarray.ravel(reduced_X[:,1:]),
                hue=data['Species'])
plt.title("2 component PCA in Iris Dataset")
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.grid()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Anaconda/envs/MachineLearning/lib/python3.11/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~/Anaconda/envs/MachineLearning/lib/python3.11/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/Anaconda/envs/MachineLearning/lib/python3.11/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Species'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 4
#       1 plt.figure(figsize=(7,7))
#       2 sns.scatterplot(x=np.ndarray.ravel(reduced_X[:,:1]),
#       3                 y=np.ndarray.ravel(reduced_X[:,1:]),
# ----> 4                 hue=data['Species'])
#       5 plt.title("2 component PCA in Iris Dataset")
#       6 plt.xlabel('Principal Component 1')
#
# File ~/Anaconda/envs/MachineLearning/lib/python3.11/site-packages/pandas/core/frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~/Anaconda/envs/MachineLearning/lib/python3.11/site-packages/pandas/core/indexes/base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'Species'

# %% [markdown]
# ## 2 - Implementing PCA for Breast cancer dataset using scikit learn

# %%
from sklearn.datasets import load_breast_cancer
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA 
from sklearn.preprocessing import StandardScaler
import numpy as np

# %%
data = load_breast_cancer()
X = data['data']

# %%
scaled_X= StandardScaler().fit_transform(X)
reduced_X = PCA(n_components=2).fit_transform(scaled_X)

# %%
plt.figure(figsize=(7,7))
sns.scatterplot(x=np.ndarray.ravel(reduced_X[:,:1]),
                y=np.ndarray.ravel(reduced_X[:,1:]),
                hue=data['target'])
plt.title("2 Component PCA in Breast Cancer Dataset using Sklearn")
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.grid()
